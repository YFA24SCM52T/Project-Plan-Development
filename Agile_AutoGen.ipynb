# %%
from autogen import ConversableAgent

# %%
llm_config = [
    {
        "model": "gpt-4o-mini",
        "api_key": "sk-j7HR-Hx3ZClCrxcJwGiOpfafshi_jNRy9U9nNySFHnT3BlbkFJx5KePtp8U7Uc-UXZB9DK6kL7Wos0fBO97Gc5Y0JKIA",
        "temperature": 0.5,
        "max_tokens": 2048
    }
]

# %%
from autogen import ConversableAgent


# Customer Proxy Agent (Admissions Department)
customer_proxy_agent = ConversableAgent(
    name="customer_proxy",
    system_message=(
        """You are representing a university's admissions department, responsible for conveying the comprehensive requirements for building an all-encompassing university application portal. The system should enable prospective students to create accounts, apply for programs, upload necessary documents, track the status of their application, and receive timely notifications throughout the admission process. 
          In your response, do not draw or create any images; focus solely on text.
        Additionally, the portal must seamlessly integrate with the university's existing student management system for syncing records, a staff dashboard for application reviews, a Canvas learning management system for course registration and assignments, a library system for accessing resources, and a financial aid platform for scholarships and tuition management. The goal is to create a unified, user-friendly system that supports every phase of the student lifecycle."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The representative of the university's admissions department"
)


project_manager_agent = ConversableAgent(
    name="project_manager",
    system_message=(
        """You are a highly experienced project manager with expertise in the education domain, overseeing the development of a new university application portal. Your role involves managing the coordination between cross-functional teams such as requirement engineers, system engineers, and software developers to ensure the portal is delivered on time, within scope, and aligned with the specific needs of the education sector. 
        In your response, do not draw or create any images; focus solely on text.
        You are responsible for ensuring the portal supports critical features like student admissions, document uploads, application tracking, notifications, integration with the university's student management system, Canvas for course management, library access, and financial aid management. You are well-versed in addressing the unique challenges of educational technology projects, ensuring compliance with academic standards, and delivering a seamless user experience for students, faculty, and administrative staff.

        Then, calculate the {effort} needed to create the project plan in hours, days, weeks, or months by following these steps:

        Step 1: Determine the {work}, which is the estimated total number of tasks and components to be included in the project plan.
        Step 2: Define the productivity rate as {3 tasks completed per day}.
        Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        The amount of {work} in this phase is based on the total number of tasks documented for all phases of the project.

        After calculating the effort, prepare the project plan for review by compiling all documented components and ensuring clarity and completeness. 

        Once prepared, conduct a thorough review of the project plan with the stakeholders, making necessary adjustments based on their feedback.    
        """
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The project manager with expertise in education, overseeing the university application portal development"
)


# Requirement Engineer Agent
requirement_engineer_agent = ConversableAgent(
    name="requirement_engineer_agent",
    system_message=(
        """You are a requirement engineer tasked with gathering detailed requirements for a university application portal. 
        Your role is to identify key use cases such as student registration, document uploads, application tracking, 
        notifications, and integration with the university’s student management system. Be thorough in breaking down 
        each requirement into clear, actionable steps.
        In your response, do not draw or create any images; focus solely on text.
        Then, calculate the {effort} needed to create the requirements document in hours, days, weeks, or months by following these steps:

        Step 1: Determine the {work}, which is the estimated total number of requirements for all use-cases required for the software project.
        Step 2: Define the productivity rate as {5 requirements completed per day}.
        Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        The amount of {work} in this phase is based on the total number of requirements documented for all use-cases in the project."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The engineer gathering detailed requirements for the university application portal"
)


# System Engineer Agent
system_engineer_agent = ConversableAgent(
    name="system_engineer_agent",
    system_message=(
        """You are a system engineer responsible for designing the architecture of a university application portal. Your 
        task is to create a detailed design document based on the requirements provided, focusing on the system’s 
        architecture, UI webpage design, API design, database design, integration with external systems, env & lab setup and scalability. Ensure that the system can 
        handle large volumes of student applications while maintaining security and performance.

        In your response, do not draw or create any images; focus solely on text.

        The System Engineer estimates the number of pages for each design element in the design document based on the number of requirements in the requirements document.

        Then, calculate the {effort} to create the design document in hours, days, weeks, or months by following these steps:

        Step 1: Determine the {work}, which is the estimated total number of pages in the design document for the software project.
        Step 2: Define the productivity rate as {2 pages completed every day}.
        Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        The amount of {work} in this phase is measured by the total number of pages in the design document created 
        based on the total number of requirements in the requirements document prepared by the requirement engineer for the software project."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The engineer designing the architecture and system for the university application portal"
)

# Software Engineer Agent
software_engineer_agent = ConversableAgent(
    name="software_engineer_agent",
    system_message=(
       """As a software engineer, your primary responsibility is to write and develop the source code for the university application portal, based on the design elements outlined by the system engineer and the requirements gathered by the requirement engineer. You will follow a systematic approach to implement each component, ensuring functionality, performance, and scalability.
        In your response, do not draw or create any images; focus solely on text.
        You will estimate the total number of source lines of code (SLOC) required for each design element. such as for Front end componenst navigation bar, pages, integration with canvas, etc

        To calculate the {effort} required to write the source code, follow these steps:

        Step 1: Determine the {work}, which is the estimated total number of lines of code (SLOC) that will be written for the software project.
        Step 2: Define the productivity rate as {50 SLOC completed per day}.
        Step 3: Calculate the {effort} using the formula: {effort} = {work} / {productivity rate}.

        The amount of {work} is based on the total number of lines of code required to implement all design elements of the project."""
    ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The engineer responsible for writing the source code for the university application portal"
)


# Test Engineer Agent
test_engineer_agent = ConversableAgent(
    name="test_engineer",
    system_message="""First, create the detailed test plan document, which has all test cases, and execute the test cases based on the 
    software written by the software engineer, the design document created by the system engineer, and the requirements 
    document created by the requirement engineer.

    In your response, do not draw or create any images; focus solely on text.

    The Test Engineer estimates the number of test cases in the test plan based on the number of requirements in the 
    requirements document.

    Then, calculate the {effort} to write and execute the test cases in hours, days, weeks, or months, following the 
    steps below:
    - Step 1: work = {the estimate of total number of test cases that will be created and executed for the software project}
    - Step 2: productivity rate = {2 test cases completed every day}
    - Step 3: effort = {work}/{productivity}.
    """,
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The engineer responsible for creating and executing test cases for the project"
)


# Documentation Engineer Agent
documentation_engineer_agent = ConversableAgent(
    name="documentation_engineer",
    system_message=(
       """ First, create the detailed documentation, which includes user documentation and training material based on the 
           software written by the software engineer, the design document created by the system engineer, and the requirements 
           document created by the requirement engineer. In your response, do not draw or create any images; focus solely on text.

           The Documentation Engineer estimates the number of pages for the documentation based on the number of requirements 
           in the requirements document, the number of pages in the design document, and the total number of SLOC written.

           Then, calculate the {effort} to write documentation pages in hours, days, weeks, or months, following the steps below:
           - Step 1: work = {the estimate of total number of documentation pages that will be created for the software project}
           - Step 2: productivity rate = {3 pages completed every day}
           - Step 3: effort = {work}/{productivity}."""
               ),
    llm_config={"config_list": llm_config},
    human_input_mode="NEVER",
    description="The engineer responsible for creating user documentation and training material for the project"
)

# %%
from autogen import GroupChat

# %%
group_chat = GroupChat(
    agents=[
        project_manager_agent, # Project Manager monitors throughout
        requirement_engineer_agent,  # Start with requirement gathering
        system_engineer_agent,  # After requirements, move to system design
        software_engineer_agent,  # After system design, start development
        test_engineer_agent,  # After development, move to testing
        documentation_engineer_agent,  # After testing, create documentation
        customer_proxy_agent  # Customer Proxy to give final plan and discuss the timeline
    ],
    messages=[],  # Start with an empty message list
    send_introductions=True,  # Introduce each agent at the start
    speaker_selection_method="auto",  # Automatically selects the next speaker in the Waterfall sequence
    max_round=9  # Limit the number of interaction rounds
)

# %%
from autogen import GroupChatManager

# %%
group_chat_manager = GroupChatManager(
    groupchat=group_chat,
    llm_config={"config_list": [{"model": "gpt-4o-mini",
                                 "api_key": "sk-j7HR-Hx3ZClCrxcJwGiOpfafshi_jNRy9U9nNySFHnT3BlbkFJx5KePtp8U7Uc-UXZB9DK6kL7Wos0fBO97Gc5Y0JKIA"}]},

)

# %%
chat_result = customer_proxy_agent.initiate_chat(
    group_chat_manager,
    message="We need to create a detailed project plan for the development of the university application portal. Each member of the team (software_engineer_agent, Requirement Engineer, System Engineer, documentation_engineer_agent) will contribute by defining their part of the plan. We will gather requirements, design the architecture, and estimate the effort required for each phase of the project.",
    summary_method="reflection_with_llm", 
)
# Out:
# customer_proxy (to chat_manager):
#
# We need to create a detailed project plan for the development of the university application portal. Each member of the team (software_engineer_agent, Requirement Engineer, System Engineer, documentation_engineer_agent) will contribute by defining their part of the plan. We will gather requirements, design the architecture, and estimate the effort required for each phase of the project.
#
# --------------------------------------------------------------------------------
#
# Next speaker: project_manager
#
# project_manager (to chat_manager):
#
# Absolutely, creating a detailed project plan is crucial for the successful development of the university application portal. Here’s how we can proceed:
#
# ### Step 1: Determine the Work
# We need to outline all the tasks and components that will be included in the project plan. Below is a preliminary breakdown of the main phases and tasks:
#
# 1. **Requirements Gathering**
# ...
