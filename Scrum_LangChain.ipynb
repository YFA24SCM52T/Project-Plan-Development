# %%
import autogen

# %%
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()
# Out:
# False

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains import ConversationChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate
)

# %%
from langchain.chains import LLMChain
from langchain.prompts.chat import (
    ChatPromptTemplate,
    SystemMessagePromptTemplate,
    HumanMessagePromptTemplate
)
from langchain.memory import ConversationBufferMemory

class Agent:
    def __init__(self, name, system_prompt, llm):
        self.name = name
        self.llm = llm
        self.system_prompt = system_prompt
        # Create a chat prompt that includes 'conversation_history'
        self.chat_prompt = ChatPromptTemplate.from_messages([
            SystemMessagePromptTemplate.from_template(self.system_prompt),
            # Include the conversation history and the last message in the prompt
            HumanMessagePromptTemplate.from_template("{conversation_history}\n{input}")
        ])
        self.chain = LLMChain(
            llm=self.llm,
            prompt=self.chat_prompt,
            verbose=False
        )

    def respond(self, input_text, conversation_history):
        response = self.chain.predict(
            input=input_text,
            conversation_history=conversation_history
        )
        return response

# %%
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0.7,
    openai_api_key=os.getenv("OPENAI_API_KEY"))

# %%
customer_proxy_agent = Agent(
    name="Customer_Proxy",
    system_prompt=(
        
        "As the Customer Proxy representing the university’s admissions department, your role is to gather comprehensive requirements for a university application portal, supporting features like account creation, program applications, document uploads, and real-time data syncing with systems like Student Management, Canvas LMS, and Financial Aid."
    ),
    llm=llm
)

# %%
project_manager_agent = Agent(
    name="Project_Manager",
    system_prompt=(
        
        "As the Project Manager, oversee the agile development of the university application portal, managing cross-functional coordination to ensure timely delivery within scope, focusing on incremental value, stakeholder feedback, and user-centered experience at each sprint."
    ),
    llm=llm
)

# %%
requirement_engineer_agent = Agent(
    name="Requirement_Engineer",
    system_prompt=(
        
        "As the Requirement Engineer, create and refine the requirements document for the university application portal, breaking down key use cases into detailed user stories and continuously collaborating with stakeholders to align with sprint goals and feedback."
    ),
    llm=llm
)

# %%
system_engineer_agent = Agent(
    name="System_Engineer",
    system_prompt=(
        
        "As the System Engineer, design an iterative, modular architecture for the university portal, covering system architecture, UI design, database schema, and integrations, adapting to evolving requirements with each sprint."
    ),
    llm=llm
)

# %%
software_engineer_agent = Agent(
    name="Software_Engineer",
    system_prompt=(
        
        "As the Software Engineer, iteratively develop source code for the university portal based on evolving requirements, focusing on functionality, performance, and scalability, and breaking down tasks aligned with sprint goals."
    ),
    llm=llm
)

# %%
test_engineer_agent = Agent(
    name="Test_Engineer",
    system_prompt=(
        
        "As the Test Engineer, create and execute test cases for each sprint to ensure software quality and performance, continuously adapting test plans as new features are developed and aligning with project requirements."
    ),
    llm=llm
)

# %%
documentation_engineer_agent = Agent(
    name="Documentation_Engineer",
    system_prompt=(
        
        "As the Documentation Engineer, create user documentation and training materials for the university portal, estimating effort based on the total documentation pages needed and maintaining alignment with updated project features."
    ),
    llm=llm
)

# %%
# Define all necessary prompt messages for the Scrum agents

# Prompt for Product Owner (Customer Proxy)
product_owner_backlog_prompt = (

        "You are representing a university’s admissions department, responsible for gathering comprehensive requirements to develop an all-inclusive, iterative university application portal. "
        "The system should support prospective students in creating accounts, applying for programs, uploading required documents, tracking application status, and receiving regular notifications throughout the admissions process."
        "\n\nUsing agile principles, prioritize iterative, value-driven development with continuous feedback from end users, including prospective students, admissions staff, and support teams. "
        "Your goal is to outline a phased, flexible approach that integrates seamlessly with the university’s current systems, focusing on adaptability and stakeholder collaboration."
        "\n\nThe portal must provide real-time data syncing with:"
        "\n- Student Management System: For updating and maintaining student records."
        "\n- Staff Dashboard: For admission team reviews and application processing."
        "\n- Canvas LMS: For course enrollment, assignments, and announcements."
        "\n- Library System: For managing student access to academic resources."
        "\n- Financial Aid Platform: For overseeing scholarships, loans, and tuition payments."
        "\n\nAt each stage of the agile cycle, deliver a unified, user-centered system that enhances each phase of the student lifecycle—from application to enrollment and beyond."
)

# Prompt for Scrum Master (Project Manager)
scrum_master_sprint_planning_prompt = (

        "You are a highly experienced Project Manager with expertise in the education domain, overseeing the agile development of a new university application portal. "
        "Your role involves managing coordination across cross-functional teams, including requirement engineers, system engineers, and software developers, to deliver the portal iteratively, on time, and within scope while meeting the specific needs of the education sector."
        "\n\nUsing agile principles, focus on delivering value incrementally with each sprint, incorporating feedback from stakeholders at regular intervals, and ensuring alignment with the evolving requirements of the portal. "
        "Key features to prioritize in each sprint include student admissions, document uploads, application tracking, notifications, and seamless integrations with the university’s Student Management System, Canvas for course management, library access, and financial aid management."
        "\n\nTo estimate the user stories for each sprint:"
        "\n- Step 1: Break down the project into smaller, manageable user stories with story numbers for each sprint, prioritizing features that bring the highest value to users."
        "\n- Step 2: Define the team’s productivity rate for this sprint, such as the average number of user story points completed per sprint."
        "\n- Step 3: Size each user story using the Fibonacci sequence (1, 2, 3, 5, 8, 13, etc.), where 1 point equals 8 hours of work."
        "\n- Step 4: Prepare a Program Increment (PI) plan, with each PI including six sprints, to enable structured planning and tracking of project progress over time."
        "\n\nAt the end of each sprint, review and adjust the project plan based on feedback received and progress made, ensuring flexibility to adapt to changing priorities. "
        "The goal is to deliver a seamless, user-centered experience for students, faculty, and administrative staff, with a clear focus on continuous improvement and stakeholder satisfaction."
)

# Prompt for Requirement Engineer
requirement_engineer_prompt = (

        "You are a Requirement Engineer Agent. Your role is to create the requirements document that includes the requirements for key use cases of a university application portal. "
        "This involves identifying and detailing use cases such as student registration, document uploads, application tracking, notifications, and integration with the university’s student management system."
        "\n\nUsing agile principles, gather and refine requirements incrementally, breaking down each use case into user stories with assigned story numbers and actionable steps. "
        "Continuously collaborate with stakeholders to validate and adapt requirements based on ongoing feedback, ensuring alignment with project goals at each sprint."
        "\n\nTo estimate the user stories for each sprint:"
        "\n- Step 1: Identify the user stories for each sprint based on prioritized use cases and assign story numbers. Estimate the total number of user stories to be documented."
        "\n- Step 2: Set the productivity rate for the sprint, with an average of 1 user story point completed per day."
        "\n- Step 3: Calculate the user story points for the sprint using the formula: user story points = user stories / productivity rate."
        "\n\nContinuously adjust the requirements document based on stakeholder feedback at the end of each sprint to ensure requirements remain relevant and actionable for the development team."
)

# Prompt for System Engineer
system_design_prompt = (

        "You are a System Engineer Agent. Your role is to create an iterative, modular design document for the architecture of a university application portal that evolves with each sprint. The design document should cover system architecture, UI design, API structure, database schema, integration with external systems, environment setup, scalability, and security considerations."
        "\n\nUsing agile principles, design incrementally based on evolving requirements and prioritize flexibility to adjust the architecture as new features and updates are introduced in each sprint. Collaborate with cross-functional teams to ensure alignment with the project’s goals, focusing on designing a system capable of handling high volumes of student applications while maintaining performance and security."
        "\n\nTo estimate the user stories for each sprint, follow these steps:"
        "\n- Step 1: Identify the user stories with a story number for each sprint by estimating the number of design elements required based on prioritized requirements for that sprint."
        "\n- Step 2: Set the productivity rate at 2 user stories completed per day."
        "\n- Step 3: Calculate the user story points for the sprint using the formula: user story points = user stories / productivity rate, where user stories is the estimated number of user stories for the sprint."
        "\n\nContinuously review and refine the design document based on feedback and changing requirements at the end of each sprint, ensuring the system architecture remains aligned with the evolving needs of the application."
)

# Prompt for Software Engineer
development_implementation_prompt = (

    
        "You are a Software Engineer Agent. Your primary responsibility is to iteratively develop the source code for the university application portal based on design specifications provided by the system engineer and evolving requirements from the requirement engineer. Your focus is on implementing each component with high functionality, performance, and scalability, while adapting to new insights and changes introduced in each sprint."
        "\n\nFollowing agile principles, develop each feature incrementally, breaking down the code into manageable tasks aligned with sprint goals. Collaborate closely with cross-functional teams, and prioritize continuous improvement and stakeholder feedback to enhance each feature progressively."
        "\n\nTo estimate the user stories for each sprint, follow these steps:"
        "\n- Step 1: Identify the user stories with a story number for each sprint by estimating the source lines of code (SLOC) required based on prioritized design elements."
        "\n- Step 2: Set the productivity rate as 50 SLOC completed per day."
        "\n- Step 3: Calculate the user story points for the sprint using the formula: user story points = SLOC / productivity rate, where SLOC is the estimated lines of code for the sprint."
        "\n\nContinuously refine code based on feedback and testing at the end of each sprint, ensuring the system aligns with the evolving needs of the application portal and adheres to quality and performance standards."
)

# Prompt for Test Engineer
testing_strategy_prompt = (

        "You are a Test Engineer Agent. Your role is to create and execute test cases iteratively based on the code written by the software engineer, the design document by the system engineer, and the requirements document by the requirement engineer. Your focus is to ensure software quality, functionality, and performance by validating each feature incrementally in alignment with each sprint."
        "\n\nUsing agile principles, develop test cases incrementally as new features are introduced in each sprint, and perform continuous testing to support rapid feedback loops and early detection of issues. Prioritize test automation for regression testing and adapt your test plan as the project evolves."
        "\n\nTo estimate the user stories for each sprint, follow these steps:"
        "\n- Step 1: Identify the user stories with a story number for each sprint, estimating the number of test cases based on the requirements and design for that sprint."
        "\n- Step 2: Set the productivity rate at 2 test cases completed per day."
        "\n- Step 3: Calculate the user story points for the sprint using the formula: user story points = test cases / productivity rate, where test cases is the estimated number of test cases for the sprint."
        "\n\nContinuously update and execute test cases at the end of each sprint, focusing on comprehensive coverage and alignment with project requirements."
    
)

# Prompt for Documentation Engineer
documentation_creation_prompt = (
    
        "You are a Documentation Engineer Agent. Your role is to create the detailed documentation which includes user documentation and training material based on the software written by the software engineer, design document created by the system engineer, and requirements document created by the requirement engineer."
        "\n\nThen calculate the {{effort}} to write documentation pages in the documentation and training phase in hours, days, weeks, or months, follow the steps below:"
        "\n- Step 1: Work = the estimate of total number of documentation pages that will be created for the software project."
        "\n- Step 2: Productivity rate = 3 pages completed every day."
        "\n- Step 3: Effort = Work / Productivity rate."
        "\n\nThe amount of {{work}} in this phase is measured by the total number of documentation pages based on the total number of requirements, design document pages, and total number of SLOC written."
    
)

# %%
# Define the chat flow and recipients with necessary 'message' keys for each recipient
scrum_chat_queue = [
    {"recipient": customer_proxy_agent, "message": product_owner_backlog_prompt},
    {"recipient": project_manager_agent, "message": scrum_master_sprint_planning_prompt},
    {"recipient": requirement_engineer_agent, "message": requirement_engineer_prompt},
    {"recipient": system_engineer_agent, "message": system_design_prompt},
    {"recipient": software_engineer_agent, "message": development_implementation_prompt},
    {"recipient": test_engineer_agent, "message": testing_strategy_prompt},
    {"recipient": documentation_engineer_agent, "message": documentation_creation_prompt}
]

# %%
team_outputs = {}

# %%
def initiate_scrum_chats(scrum_chat_queue):
    # Initialize conversation history
    conversation_history = product_vision_message
    team_outputs = {}

    # Iterate through each agent in the queue
    for i, chat in enumerate(scrum_chat_queue):
        recipient = chat['recipient']
        message = chat['message']

        # Print current speaker information
        print(f"Initiating chat with {recipient.name.replace('_', ' ')}")

        # Provide the required input_text argument to respond
        response = recipient.respond(input_text=message, conversation_history=conversation_history)

        # Store response in team outputs and accumulate in conversation history
        team_outputs[recipient.name] = {
            "speaker": recipient.name,
            "input_message": message,
            "response": response
        }
        conversation_history += f"\n{recipient.name}: {response}\n"

    return team_outputs

# %%
def compile_final_scrum_report(team_outputs):
    final_scrum_report = "### Final Scrum Report\n\nThe sprint has been completed. Below is the final report detailing the work done by each team member:\n\n"

    # Add a section for each team member
    for member, details in team_outputs.items():
        final_scrum_report += f"{member.replace('_', ' ')}:\n"
        final_scrum_report += f"  - Message:\n{details['input_message']}\n"
        final_scrum_report += f"  - Response:\n{details['response']}\n\n"

    final_scrum_report += "### Conclusion:\nThe sprint has been completed successfully, and the team is ready for the next sprint."
    
    return final_scrum_report

# %%
# Product vision message that sets the initial context
product_vision_message = "Define the vision and high-level goals for the university application portal."

# Execute the Scrum chat sequence and compile the final report
team_outputs = initiate_scrum_chats(scrum_chat_queue)
final_report = compile_final_scrum_report(team_outputs)

# Print the final report
print(final_report)
# Out:
# Initiating chat with Customer Proxy
# Initiating chat with Project Manager
# Initiating chat with Requirement Engineer
# Initiating chat with System Engineer
# Initiating chat with Software Engineer
# Initiating chat with Test Engineer
# Initiating chat with Documentation Engineer
# ### Final Scrum Report
#
# The sprint has been completed. Below is the final report detailing the work done by each team member:
#
# Customer Proxy:
#   - Message:
# You are representing a university’s admissions department, responsible for gathering comprehensive requirements to develop an all-inclusive, iterative university application portal. The system should support prospective students in creating accounts, applying for programs, uploading required documents, tracking application status, and receiving regular notifications throughout the admissions process.
#
# Using agile principles, prioritize iterative, value-driven development with continuous feedback from end users, including prospective students, admissions staff, and support teams. Your goal is to outline a phased, flexible approach that integrates seamlessly with the university’s current systems, focusing on adaptability and stakeholder collaboration.
#
# The portal must provide real-time data syncing with:
# - Student Management System: For updating and maintaining student records.
# - Staff Dashboard: For admission team reviews and application processing.
# - Canvas LMS: For course enrollment, assignments, and announcements.
# - Library System: For managing student access to academic resources.
# - Financial Aid Platform: For overseeing scholarships, loans, and tuition payments.
#
# At each stage of the agile cycle, deliver a unified, user-centered system that enhances each phase of the student lifecycle—from application to enrollment and beyond.
#   - Response:
# **Vision for the University Application Portal**
#
# The university application portal aims to provide a streamlined, user-friendly experience for prospective students as they navigate the application process. The portal will empower applicants with the tools and information needed to manage their applications efficiently while fostering seamless communication between the admissions department and applicants. By integrating with existing systems, the portal will ensure that data flows smoothly across departments, enhancing operational efficiency and improving the overall student experience from application through enrollment and beyond.
#
# **High-Level Goals**
#
# 1. **User-Centric Design:**
#    - Develop an intuitive interface that caters to the needs of prospective students, ensuring easy navigation and accessibility.
#    - Implement user feedback mechanisms to continuously improve the user experience.
#
# 2. **Comprehensive Application Management:**
#    - Enable prospective students to create accounts, apply for multiple programs, and upload necessary documents in a secure environment.
#    - Allow for tracking of application statuses, providing real-time updates on the progress of applications.
#
# 3. **Seamless Integration with University Systems:**
#    - Ensure real-time data syncing with existing systems (Student Management, Canvas LMS, Financial Aid, etc.) to maintain accurate and up-to-date information across the university’s departments.
#    - Facilitate a unified view for admissions staff to review applications and communicate with prospective students effectively.
#
# 4. **Enhanced Communication and Notifications:**
#    - Provide regular notifications to applicants regarding application milestones, deadlines, and required actions.
#    - Create a communication channel for applicants to reach out to admissions staff for assistance and inquiries.
#
# 5. **Iterative Development and Continuous Improvement:**
#    - Adopt agile methodologies to develop the portal in phases, integrating user feedback at each step to refine features and functionality.
#    - Prioritize features based on stakeholder input, ensuring the most valuable enhancements are delivered first.
#
# 6. **Data Security and Compliance:**
#    - Implement robust security measures to protect sensitive applicant data in compliance with regulatory requirements and university policies.
#    - Ensure that the portal is accessible to all users, including those with disabilities, in accordance with accessibility standards.
#
# 7. **Support for the Entire Student Lifecycle:**
#    - Design the portal to facilitate not only the application phase but also the transition to enrollment and ongoing engagement with university resources.
#    - Integrate features that assist applicants in understanding financial aid options, course enrollment, and accessing academic resources.
#
# **Phased Approach for Development**
#
# 1. **Phase 1: Account Creation and Program Applications**
#    - Develop the foundational features for account creation and program selection.
#    - Gather user feedback on usability and functionality before proceeding to the next phase.
#
# 2. **Phase 2: Document Uploads and Application Tracking**
#    - Implement secure document upload capabilities and a tracking system for application statuses.
#    - Solicit feedback from both applicants and admissions staff to refine these features.
#
# 3. **Phase 3: Notifications and Communication Tools**
#    - Introduce notification systems to keep applicants informed and establish communication channels with admissions staff.
#    - Evaluate effectiveness through user testing and adjust as necessary.
#
# 4. **Phase 4: Integration with University Systems**
#    - Begin real-time data syncing with the Student Management System, Canvas LMS, and Financial Aid Platform.
#    - Test integration thoroughly with stakeholders to ensure seamless operation.
#
# 5. **Phase 5: Continuous Improvement and Feature Enhancements**
#    - Gather ongoing feedback from users to identify further areas for improvement.
#    - Implement additional features based on priority, such as financial aid tracking, library access, or enhanced reporting for admissions staff.
#
# By following this vision and high-level goals, the university application portal will evolve into a comprehensive solution that meets the needs of prospective students and supports the university's admissions staff effectively. Continuous engagement with users will ensure the portal remains relevant and valuable throughout its lifecycle.
#
# Project Manager:
#   - Message:
# You are a highly experienced Project Manager with expertise in the education domain, overseeing the agile development of a new university application portal. Your role involves managing coordination across cross-functional teams, including requirement engineers, system engineers, and software developers, to deliver the portal iteratively, on time, and within scope while meeting the specific needs of the education sector.
#
# Using agile principles, focus on delivering value incrementally with each sprint, incorporating feedback from stakeholders at regular intervals, and ensuring alignment with the evolving requirements of the portal. Key features to prioritize in each sprint include student admissions, document uploads, application tracking, notifications, and seamless integrations with the university’s Student Management System, Canvas for course management, library access, and financial aid management.
#
# To estimate the user stories for each sprint:
# - Step 1: Break down the project into smaller, manageable user stories with story numbers for each sprint, prioritizing features that bring the highest value to users.
# - Step 2: Define the team’s productivity rate for this sprint, such as the average number of user story points completed per sprint.
# - Step 3: Size each user story using the Fibonacci sequence (1, 2, 3, 5, 8, 13, etc.), where 1 point equals 8 hours of work.
# - Step 4: Prepare a Program Increment (PI) plan, with each PI including six sprints, to enable structured planning and tracking of project progress over time.
#
# At the end of each sprint, review and adjust the project plan based on feedback received and progress made, ensuring flexibility to adapt to changing priorities. The goal is to deliver a seamless, user-centered experience for students, faculty, and administrative staff, with a clear focus on continuous improvement and stakeholder satisfaction.
#   - Response:
# **User Story Breakdown for the University Application Portal Development**
#
# **Sprint 1: Account Creation and Program Applications**
# - **User Story 1.1**: As a prospective student, I want to create an account so that I can start my application process.
#   - **Story Points**: 3
# - **User Story 1.2**: As a prospective student, I want to select from multiple programs so that I can apply to the ones that interest me.
#   - **Story Points**: 5
# - **User Story 1.3**: As an admissions staff member, I want to view the list of applicants and their selected programs so that I can manage applications effectively.
#   - **Story Points**: 3
#
# **Total Story Points for Sprint 1**: 11
#
# ---
#
# **Sprint 2: Document Uploads and Application Tracking**
# - **User Story 2.1**: As a prospective student, I want to upload required documents securely so that my application is complete.
#   - **Story Points**: 5
# - **User Story 2.2**: As a prospective student, I want to track the status of my application in real-time so that I know where I stand in the process.
#   - **Story Points**: 8
# - **User Story 2.3**: As an admissions staff member, I want to view uploaded documents and application statuses so that I can assess applications efficiently.
#   - **Story Points**: 5
#
# **Total Story Points for Sprint 2**: 18
#
# ---
#
# **Sprint 3: Notifications and Communication Tools**
# - **User Story 3.1**: As a prospective student, I want to receive notifications about important application deadlines so that I don’t miss any critical steps.
#   - **Story Points**: 3
# - **User Story 3.2**: As a prospective student, I want a communication channel to ask questions to admissions staff so that I can get help when needed.
#   - **Story Points**: 5
# - **User Story 3.3**: As an admissions staff member, I want to send notifications to applicants regarding their application status updates so that they are informed.
#   - **Story Points**: 3
#
# **Total Story Points for Sprint 3**: 11
#
# ---
#
# **Sprint 4: Integration with University Systems**
# - **User Story 4.1**: As a systems engineer, I want to integrate the application portal with the Student Management System so that data flows seamlessly.
#   - **Story Points**: 8
# - **User Story 4.2**: As a prospective student, I want my information to sync with the Canvas LMS so that I can access course materials once enrolled.
#   - **Story Points**: 5
# - **User Story 4.3**: As an admissions staff member, I want to view integrated data from various systems for informed decision-making.
#   - **Story Points**: 8
#
# **Total Story Points for Sprint 4**: 21
#
# ---
#
# **Sprint 5: Continuous Improvement and Feature Enhancements**
# - **User Story 5.1**: As a prospective student, I want to have access to financial aid information directly from the portal so that I can make informed choices.
#   - **Story Points**: 5
# - **User Story 5.2**: As an admissions staff member, I want enhanced reporting tools to analyze application trends and improve decision-making.
#   - **Story Points**: 8
# - **User Story 5.3**: As a prospective student, I want to access library resources from the portal to support my academic needs.
#   - **Story Points**: 5
#
# **Total Story Points for Sprint 5**: 18
#
# ---
#
# **Sprint 6: Final Adjustments and User Testing**
# - **User Story 6.1**: As a prospective student, I want to provide feedback on my experience using the portal so that improvements can be made.
#   - **Story Points**: 3
# - **User Story 6.2**: As an admissions staff member, I want to participate in user testing sessions to ensure the portal meets our needs.
#   - **Story Points**: 3
# - **User Story 6.3**: As a project manager, I want to review all feedback and make necessary adjustments before the final launch.
#   - **Story Points**: 5
#
# **Total Story Points for Sprint 6**: 11
#
# ---
#
# ### Team's Productivity Rate and PI Plan
#
# Assuming the development team averages 20 story points per sprint, the following Program Increment (PI) plan can be established:
#
# 1. **PI 1**:
#    - Sprint 1: 11 Points
#    - Sprint 2: 18 Points
#    - Sprint 3: 11 Points
#    - Sprint 4: 21 Points
#    - Sprint 5: 18 Points
#    - Sprint 6: 11 Points
#    - **Total for PI 1**: 90 Points
#
# 2. **Adjustments and Flexibility**: At the end of each sprint, we will conduct a sprint review and retrospective to assess the completed work, feedback from stakeholders, and any adjustments needed for upcoming sprints. This will keep the project aligned with user needs and ensure continuous improvement.
#
# By following this structured approach, we will ensure timely delivery of high-value features, enhance user experience, and maintain stakeholder satisfaction throughout the development of the university application portal.
#
# Requirement Engineer:
#   - Message:
# You are a Requirement Engineer Agent. Your role is to create the requirements document that includes the requirements for key use cases of a university application portal. This involves identifying and detailing use cases such as student registration, document uploads, application tracking, notifications, and integration with the university’s student management system.
#
# Using agile principles, gather and refine requirements incrementally, breaking down each use case into user stories with assigned story numbers and actionable steps. Continuously collaborate with stakeholders to validate and adapt requirements based on ongoing feedback, ensuring alignment with project goals at each sprint.
#
# To estimate the user stories for each sprint:
# - Step 1: Identify the user stories for each sprint based on prioritized use cases and assign story numbers. Estimate the total number of user stories to be documented.
# - Step 2: Set the productivity rate for the sprint, with an average of 1 user story point completed per day.
# - Step 3: Calculate the user story points for the sprint using the formula: user story points = user stories / productivity rate.
#
# Continuously adjust the requirements document based on stakeholder feedback at the end of each sprint to ensure requirements remain relevant and actionable for the development team.
#   - Response:
# # Requirements Document for the University Application Portal
#
# ## Vision Statement
# The University Application Portal aims to provide a streamlined, user-friendly experience for prospective students navigating the application process. The portal will empower applicants with tools and information for efficient application management while fostering seamless communication with the admissions department. By integrating with existing university systems, the portal will ensure smooth data flow across departments, enhancing operational efficiency and improving the overall student experience.
#
# ## High-Level Goals
# 1. **User-Centric Design**
# 2. **Comprehensive Application Management**
# 3. **Seamless Integration with University Systems**
# 4. **Enhanced Communication and Notifications**
# 5. **Iterative Development and Continuous Improvement**
# 6. **Data Security and Compliance**
# 7. **Support for the Entire Student Lifecycle**
#
# ---
#
# ## Key Use Cases and User Stories
#
# ### Use Case 1: Student Registration
# - **User Story 1.1**: As a prospective student, I want to create an account so that I can start my application process.
#   - **Acceptance Criteria**: The user can complete registration with name, email, password, and verification.
# - **User Story 1.2**: As a prospective student, I want to reset my password so that I can regain access if I forget it.
#   - **Acceptance Criteria**: Password reset link is sent to the registered email.
#
# ### Use Case 2: Program Applications
# - **User Story 2.1**: As a prospective student, I want to select from multiple programs so that I can apply to the ones that interest me.
#   - **Acceptance Criteria**: The user can view and select various programs listed.
# - **User Story 2.2**: As an admissions staff member, I want to view the list of applicants and their selected programs so that I can manage applications effectively.
#   - **Acceptance Criteria**: Staff can filter and view applicants by program.
#
# ### Use Case 3: Document Uploads
# - **User Story 3.1**: As a prospective student, I want to upload required documents securely so that my application is complete.
#   - **Acceptance Criteria**: Users can upload files with specified formats and sizes.
# - **User Story 3.2**: As an admissions staff member, I want to view uploaded documents so that I can assess applications efficiently.
#   - **Acceptance Criteria**: Staff can download and review documents uploaded by applicants.
#
# ### Use Case 4: Application Tracking
# - **User Story 4.1**: As a prospective student, I want to track the status of my application in real-time so that I know where I stand in the process.
#   - **Acceptance Criteria**: Users can see status updates (e.g., submitted, under review, decision made).
# - **User Story 4.2**: As an admissions staff member, I want to update application statuses so that applicants receive current information.
#   - **Acceptance Criteria**: Staff can change the status of an application and notify applicants.
#
# ### Use Case 5: Notifications and Communication
# - **User Story 5.1**: As a prospective student, I want to receive notifications about important application deadlines so that I don’t miss any critical steps.
#   - **Acceptance Criteria**: Users receive timely notifications via email and portal alerts.
# - **User Story 5.2**: As a prospective student, I want a communication channel to ask questions to admissions staff so that I can get help when needed.
#   - **Acceptance Criteria**: Users can send messages and receive responses from admissions.
#
# ### Use Case 6: Integration with University Systems
# - **User Story 6.1**: As a systems engineer, I want to integrate the application portal with the Student Management System so that data flows seamlessly.
#   - **Acceptance Criteria**: Successful data transfers between the portal and the Student Management System are verified.
# - **User Story 6.2**: As a prospective student, I want my information to sync with the Canvas LMS so that I can access course materials once enrolled.
#   - **Acceptance Criteria**: Enrollment data is accurately reflected in the Canvas LMS.
#
# ---
#
# ## User Story Estimation
#
# ### Sprint 1: Account Creation and Program Applications
# - **Total User Stories**: 3
# - **Story Points**: 11
# - **Days to Complete**: 11 days
#
# ### Sprint 2: Document Uploads and Application Tracking
# - **Total User Stories**: 3
# - **Story Points**: 18
# - **Days to Complete**: 18 days
#
# ### Sprint 3: Notifications and Communication Tools
# - **Total User Stories**: 3
# - **Story Points**: 11
# - **Days to Complete**: 11 days
#
# ### Sprint 4: Integration with University Systems
# - **Total User Stories**: 3
# - **Story Points**: 21
# - **Days to Complete**: 21 days
#
# ### Sprint 5: Continuous Improvement and Feature Enhancements
# - **Total User Stories**: 3
# - **Story Points**: 18
# - **Days to Complete**: 18 days
#
# ### Sprint 6: Final Adjustments and User Testing
# - **Total User Stories**: 3
# - **Story Points**: 11
# - **Days to Complete**: 11 days
#
# ---
#
# ## Adjustments and Continuous Improvement
# At the end of each sprint, the team will conduct a review and retrospective session to:
# - Gather feedback from stakeholders.
# - Evaluate progress against project goals.
# - Adjust user stories and requirements based on findings.
# - Prioritize future user stories to align with stakeholder feedback and project objectives.
#
# This iterative approach will ensure that the requirements document remains relevant and actionable throughout the development of the university application portal, leading to a successful project outcome.
#
# System Engineer:
#   - Message:
# You are a System Engineer Agent. Your role is to create an iterative, modular design document for the architecture of a university application portal that evolves with each sprint. The design document should cover system architecture, UI design, API structure, database schema, integration with external systems, environment setup, scalability, and security considerations.
#
# Using agile principles, design incrementally based on evolving requirements and prioritize flexibility to adjust the architecture as new features and updates are introduced in each sprint. Collaborate with cross-functional teams to ensure alignment with the project’s goals, focusing on designing a system capable of handling high volumes of student applications while maintaining performance and security.
#
# To estimate the user stories for each sprint, follow these steps:
# - Step 1: Identify the user stories with a story number for each sprint by estimating the number of design elements required based on prioritized requirements for that sprint.
# - Step 2: Set the productivity rate at 2 user stories completed per day.
# - Step 3: Calculate the user story points for the sprint using the formula: user story points = user stories / productivity rate, where user stories is the estimated number of user stories for the sprint.
#
# Continuously review and refine the design document based on feedback and changing requirements at the end of each sprint, ensuring the system architecture remains aligned with the evolving needs of the application.
#   - Response:
# # University Application Portal Architecture Design Document
#
# ## 1. Introduction
# This document outlines the iterative, modular architecture for the University Application Portal, focusing on maintaining flexibility to adapt to evolving requirements. The design incorporates system architecture, UI design, API structure, database schema, integration with external systems, environment setup, scalability, and security considerations.
#
# ## 2. System Architecture
#
# ### 2.1 Overview
# The University Application Portal will be built using a microservices architecture to facilitate modular development. Each service will be responsible for specific functionalities, allowing independent development and deployment.
#
# ### 2.2 Components
# - **Frontend**: A responsive web application built using React.js for a dynamic user experience.
# - **Backend**: Microservices developed in Node.js with Express for handling different functionalities such as user management, application processing, and notifications.
# - **Database**: MongoDB for storing user data and application information, allowing for flexible schema design.
# - **API Gateway**: A gateway to manage API requests and route them to the appropriate microservices.
# - **Authentication Service**: A dedicated service for user authentication and authorization using JWT tokens.
#
# ### 2.3 Deployment Architecture
# - **Cloud Provider**: AWS or Azure for hosting services.
# - **Containerization**: Docker for packaging microservices.
# - **Orchestration**: Kubernetes for managing containers and scaling services as needed.
# - **CI/CD Pipeline**: Jenkins or GitHub Actions for continuous integration and deployment.
#
# ## 3. UI Design
#
# ### 3.1 User Experience (UX)
# - **User-Centric Design**: Focus on intuitive navigation with clear calls-to-action.
# - **Accessibility Compliance**: Adhere to WCAG 2.1 standards to ensure accessibility for all users.
#
# ### 3.2 Wireframes
# - **Home Page**: A dashboard for prospective students to begin their application.
# - **Application Form**: A multi-step form for program selection, document uploads, and status tracking.
# - **Notifications Page**: A centralized location for alerts and updates regarding application status.
#
# ## 4. API Structure
#
# ### 4.1 RESTful API Endpoints
# - **User Management**
#   - `POST /api/users/register`: Register a new user.
#   - `POST /api/users/login`: Authenticate a user.
#   - `GET /api/users/profile`: Retrieve user profile information.
#
# - **Application Management**
#   - `POST /api/applications`: Submit a new application.
#   - `GET /api/applications/{id}`: Retrieve application details.
#   - `PUT /api/applications/{id}/status`: Update application status.
#
# - **Document Management**
#   - `POST /api/documents/upload`: Upload required documents.
#   - `GET /api/documents/{id}`: Retrieve uploaded documents.
#
# - **Notifications**
#   - `GET /api/notifications`: Fetch notifications for the user.
#   - `POST /api/notifications`: Send notifications to users.
#
# ## 5. Database Schema
#
# ### 5.1 MongoDB Collections
# - **Users**
#   - Fields: `_id`, `name`, `email`, `password`, `role`, `created_at`, `updated_at`
#
# - **Applications**
#   - Fields: `_id`, `user_id`, `program`, `status`, `submitted_at`, `updated_at`
#
# - **Documents**
#   - Fields: `_id`, `application_id`, `file_path`, `uploaded_at`
#
# - **Notifications**
#   - Fields: `_id`, `user_id`, `message`, `created_at`, `is_read`
#
# ## 6. Integration with External Systems
#
# ### 6.1 Integration Points
# - **Student Management System (SMS)**: Sync applicant data and statuses.
# - **Learning Management System (LMS)**: Sync enrolled student data for course access.
# - **Financial Aid System**: Provide financial aid information access to applicants.
#
# ### 6.2 Data Synchronization
# - Implement API calls to external systems to ensure data consistency across platforms.
#
# ## 7. Environment Setup
#
# ### 7.1 Development Environment
# - **Local Development**: Docker containers for each microservice.
# - **Version Control**: Git for source code management.
#
# ### 7.2 Testing Environment
# - Use staging servers that replicate the production environment for testing before release.
#
# ## 8. Scalability
#
# ### 8.1 Horizontal Scaling
# - Deploy additional instances of microservices based on traffic demand.
# - Use load balancers to distribute incoming requests across instances.
#
# ### 8.2 Caching
# - Implement caching strategies using Redis for frequently accessed data to improve performance.
#
# ## 9. Security Considerations
#
# ### 9.1 Data Protection
# - Implement encryption for sensitive data both at rest and in transit.
# - Use HTTPS for all API communications.
#
# ### 9.2 Authentication & Authorization
# - Utilize OAuth2 and JWT for secure user authentication and authorization.
#
# ### 9.3 Regular Security Audits
# - Conduct periodic audits to identify vulnerabilities and ensure compliance with security standards.
#
# ## 10. User Story Estimation for Sprints
#
# ### Sprint Planning
# Each sprint will focus on delivering specific user stories, with a productivity rate of 2 user stories per day.
#
# #### Sprint 1: Account Creation and Program Applications
# - **User Stories**: 3
# - **Estimated Days**: 3 days
# - **Story Points**: 3 / 2 = 1.5 (rounded to 2 points)
#
# #### Sprint 2: Document Uploads and Application Tracking
# - **User Stories**: 3
# - **Estimated Days**: 3 days
# - **Story Points**: 3 / 2 = 1.5 (rounded to 2 points)
#
# #### Sprint 3: Notifications and Communication Tools
# - **User Stories**: 3
# - **Estimated Days**: 3 days
# - **Story Points**: 3 / 2 = 1.5 (rounded to 2 points)
#
# #### Sprint 4: Integration with University Systems
# - **User Stories**: 3
# - **Estimated Days**: 3 days
# - **Story Points**: 3 / 2 = 1.5 (rounded to 2 points)
#
# #### Sprint 5: Continuous Improvement and Feature Enhancements
# - **User Stories**: 3
# - **Estimated Days**: 3 days
# - **Story Points**: 3 / 2 = 1.5 (rounded to 2 points)
#
# #### Sprint 6: Final Adjustments and User Testing
# - **User Stories**: 3
# - **Estimated Days**: 3 days
# - **Story Points**: 3 / 2 = 1.5 (rounded to 2 points)
#
# ## 11. Review and Refinement
# At the end of each sprint, feedback will be gathered to refine the architecture and adjust user stories for the following sprint. This iterative approach ensures that the architecture evolves alongside user needs and project goals.
#
# ---
#
# This design document serves as a blueprint for developing the University Application Portal, ensuring that the architecture is adaptable, scalable, and secure while continuously improving the user experience for prospective students.
#
# Software Engineer:
#   - Message:
# You are a Software Engineer Agent. Your primary responsibility is to iteratively develop the source code for the university application portal based on design specifications provided by the system engineer and evolving requirements from the requirement engineer. Your focus is on implementing each component with high functionality, performance, and scalability, while adapting to new insights and changes introduced in each sprint.
#
# Following agile principles, develop each feature incrementally, breaking down the code into manageable tasks aligned with sprint goals. Collaborate closely with cross-functional teams, and prioritize continuous improvement and stakeholder feedback to enhance each feature progressively.
#
# To estimate the user stories for each sprint, follow these steps:
# - Step 1: Identify the user stories with a story number for each sprint by estimating the source lines of code (SLOC) required based on prioritized design elements.
# - Step 2: Set the productivity rate as 50 SLOC completed per day.
# - Step 3: Calculate the user story points for the sprint using the formula: user story points = SLOC / productivity rate, where SLOC is the estimated lines of code for the sprint.
#
# Continuously refine code based on feedback and testing at the end of each sprint, ensuring the system aligns with the evolving needs of the application portal and adheres to quality and performance standards.
#   - Response:
# ### Sprint 1: Account Creation and Program Applications
#
# #### User Stories:
# 1. **User Story 1.1**: Account Creation
# 2. **User Story 1.2**: Program Selection
# 3. **User Story 1.3**: View Applicants
#
# #### Step 1: Estimate SLOC for User Stories
# - **User Story 1.1 (Account Creation)**: Estimated SLOC = 150
# - **User Story 1.2 (Program Selection)**: Estimated SLOC = 200
# - **User Story 1.3 (View Applicants)**: Estimated SLOC = 100
#
# #### Total SLOC Calculation:
# Total SLOC for Sprint 1 = 150 + 200 + 100 = **450 SLOC**
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 50 SLOC/day
#
# #### Step 3: Calculate User Story Points
# - User Story Points = SLOC / Productivity Rate = 450 / 50 = **9 Points**
#
# #### Implementation Tasks:
# 1. **Set up Project Structure** (Frontend & Backend)
#    - Create directories for frontend and backend components.
#    - Initialize a Git repository.
#
# 2. **Implement User Registration** (User Story 1.1)
#    - **Backend**: Create an endpoint for user registration.
#    - **Frontend**: Develop registration form with validation.
#    - **Database**: Define user schema in MongoDB.
#
# 3. **Implement Program Selection** (User Story 1.2)
#    - **Backend**: Create an endpoint to retrieve available programs.
#    - **Frontend**: Design a dropdown menu for program selection.
#
# 4. **Implement View Applicants** (User Story 1.3)
#    - **Backend**: Create an endpoint to fetch applicants by program.
#    - **Frontend**: Develop a UI for admissions staff to view applicants.
#
# 5. **Testing and Feedback**
#    - Conduct unit tests for backend endpoints.
#    - Perform user acceptance testing (UAT) with admissions staff.
#
# ---
#
# ### Sprint 2: Document Uploads and Application Tracking
#
# #### User Stories:
# 1. **User Story 2.1**: Document Upload
# 2. **User Story 2.2**: Application Status Tracking
# 3. **User Story 2.3**: View Uploaded Documents
#
# #### Step 1: Estimate SLOC for User Stories
# - **User Story 2.1 (Document Upload)**: Estimated SLOC = 250
# - **User Story 2.2 (Application Status Tracking)**: Estimated SLOC = 300
# - **User Story 2.3 (View Uploaded Documents)**: Estimated SLOC = 150
#
# #### Total SLOC Calculation:
# Total SLOC for Sprint 2 = 250 + 300 + 150 = **700 SLOC**
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 50 SLOC/day
#
# #### Step 3: Calculate User Story Points
# - User Story Points = SLOC / Productivity Rate = 700 / 50 = **14 Points**
#
# #### Implementation Tasks:
# 1. **Implement Document Upload** (User Story 2.1)
#    - **Backend**: Create endpoint for document uploads with validation.
#    - **Frontend**: Design upload interface to handle file submissions.
#
# 2. **Implement Application Status Tracking** (User Story 2.2)
#    - **Backend**: Create endpoint to retrieve application status.
#    - **Frontend**: Develop a status dashboard for applicants to view their progress.
#
# 3. **Implement View Uploaded Documents** (User Story 2.3)
#    - **Backend**: Create an endpoint for admissions staff to view uploaded documents.
#    - **Frontend**: Design a UI component for document review.
#
# 4. **Testing and Feedback**
#    - Conduct integration tests for document upload functionality.
#    - Perform UAT with both applicants and admissions staff.
#
# ---
#
# ### Sprint 3: Notifications and Communication Tools
#
# #### User Stories:
# 1. **User Story 3.1**: Notification System
# 2. **User Story 3.2**: Communication Channel
#
# #### Step 1: Estimate SLOC for User Stories
# - **User Story 3.1 (Notification System)**: Estimated SLOC = 200
# - **User Story 3.2 (Communication Channel)**: Estimated SLOC = 250
#
# #### Total SLOC Calculation:
# Total SLOC for Sprint 3 = 200 + 250 = **450 SLOC**
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 50 SLOC/day
#
# #### Step 3: Calculate User Story Points
# - User Story Points = SLOC / Productivity Rate = 450 / 50 = **9 Points**
#
# #### Implementation Tasks:
# 1. **Implement Notification System** (User Story 3.1)
#    - **Backend**: Create endpoint to send notifications.
#    - **Frontend**: Design UI for applicants to view notifications.
#
# 2. **Implement Communication Channel** (User Story 3.2)
#    - **Backend**: Develop messaging service for applicants to contact admissions.
#    - **Frontend**: Create a messaging interface for users.
#
# 3. **Testing and Feedback**
#    - Conduct unit tests for the notification and messaging services.
#    - Perform UAT to gather feedback on usability.
#
# ---
#
# ### Sprint 4: Integration with University Systems
#
# #### User Stories:
# 1. **User Story 4.1**: Integration with SMS
# 2. **User Story 4.2**: Sync with LMS
# 3. **User Story 4.3**: View Integrated Data
#
# #### Step 1: Estimate SLOC for User Stories
# - **User Story 4.1 (Integration with SMS)**: Estimated SLOC = 300
# - **User Story 4.2 (Sync with LMS)**: Estimated SLOC = 250
# - **User Story 4.3 (View Integrated Data)**: Estimated SLOC = 200
#
# #### Total SLOC Calculation:
# Total SLOC for Sprint 4 = 300 + 250 + 200 = **750 SLOC**
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 50 SLOC/day
#
# #### Step 3: Calculate User Story Points
# - User Story Points = SLOC / Productivity Rate = 750 / 50 = **15 Points**
#
# #### Implementation Tasks:
# 1. **Integrate with Student Management System** (User Story 4.1)
#    - Develop APIs for data exchange with the SMS.
#    - Ensure data consistency and error handling.
#
# 2. **Sync Data with Learning Management System** (User Story 4.2)
#    - Develop APIs for syncing student enrollment data with LMS.
#    - Test data flow and integrity.
#
# 3. **View Integrated Data** (User Story 4.3)
#    - Create a dashboard for admissions staff to view integrated data.
#    - Implement filtering options based on various parameters.
#
# 4. **Testing and Feedback**
#    - Conduct end-to-end testing of integrations.
#    - Gather feedback from stakeholders on the integrated functionality.
#
# ---
#
# ### Sprint 5: Continuous Improvement and Feature Enhancements
#
# #### User Stories:
# 1. **User Story 5.1**: Financial Aid Information Access
# 2. **User Story 5.2**: Enhanced Reporting Tools
# 3. **User Story 5.3**: Access Library Resources
#
# #### Step 1: Estimate SLOC for User Stories
# - **User Story 5.1 (Financial Aid Information)**: Estimated SLOC = 200
# - **User Story 5.2 (Enhanced Reporting Tools)**: Estimated SLOC = 300
# - **User Story 5.3 (Library Resources)**: Estimated SLOC = 250
#
# #### Total SLOC Calculation:
# Total SLOC for Sprint 5 = 200 + 300 + 250 = **750 SLOC**
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 50 SLOC/day
#
# #### Step 3: Calculate User Story Points
# - User Story Points = SLOC / Productivity Rate = 750 / 50 = **15 Points**
#
# #### Implementation Tasks:
# 1. **Implement Access to Financial Aid Information** (User Story 5.1)
#    - Create an endpoint for financial aid queries.
#    - Design a UI component for displaying financial aid options.
#
# 2. **Develop Enhanced Reporting Tools** (User Story 5.2)
#    - Build dashboards for admissions staff with key metrics.
#    - Implement export features for reports.
#
# 3. **Implement Access to Library Resources** (User Story 5.3)
#    - Create an interface for users to access library resources.
#    - Integrate with the library system API for real-time data.
#
# 4. **Testing and Feedback**
#    - Conduct user testing for new enhancements.
#    - Gather feedback and prioritize future improvements.
#
# ---
#
# ### Sprint 6: Final Adjustments and User Testing
#
# #### User Stories:
# 1. **User Story 6.1**: User Feedback Submission
# 2. **User Story 6.2**: Admissions Staff Testing
# 3. **User Story 6.3**: Review Feedback and Adjustments
#
# #### Step 1: Estimate SLOC for User Stories
# - **User Story 6.1 (User Feedback Submission)**: Estimated SLOC = 150
# - **User Story 6.2 (Admissions Staff Testing)**: Estimated SLOC = 100
# - **User Story 6.3 (Review and Adjustments)**: Estimated SLOC = 150
#
# #### Total SLOC Calculation:
# Total SLOC for Sprint 6 = 150 + 100 + 150 = **400 SLOC**
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 50 SLOC/day
#
# #### Step 3: Calculate User Story Points
# - User Story Points = SLOC / Productivity Rate = 400 / 50 = **8 Points**
#
# #### Implementation Tasks:
# 1. **Implement User Feedback Submission** (User Story 6.1)
#    - Create a feedback form for users to submit their experiences.
#    - Store feedback in the database for analysis.
#
# 2. **Conduct Admissions Staff Testing** (User Story 6.2)
#    - Organize sessions for admissions staff to test the portal.
#    - Collect feedback for final adjustments.
#
# 3. **Review Feedback and Make Adjustments** (User Story 6.3)
#    - Analyze feedback and prioritize changes.
#    - Implement necessary adjustments before final launch.
#
# 4. **Testing and Feedback**
#    - Conduct regression testing to ensure no critical issues.
#    - Prepare for deployment based on final feedback.
#
# ---
#
# By following this detailed plan, the development of the university application portal will remain aligned with the agile methodology, ensuring continuous improvement and adaptation to user needs throughout the process.
#
# Test Engineer:
#   - Message:
# You are a Test Engineer Agent. Your role is to create and execute test cases iteratively based on the code written by the software engineer, the design document by the system engineer, and the requirements document by the requirement engineer. Your focus is to ensure software quality, functionality, and performance by validating each feature incrementally in alignment with each sprint.
#
# Using agile principles, develop test cases incrementally as new features are introduced in each sprint, and perform continuous testing to support rapid feedback loops and early detection of issues. Prioritize test automation for regression testing and adapt your test plan as the project evolves.
#
# To estimate the user stories for each sprint, follow these steps:
# - Step 1: Identify the user stories with a story number for each sprint, estimating the number of test cases based on the requirements and design for that sprint.
# - Step 2: Set the productivity rate at 2 test cases completed per day.
# - Step 3: Calculate the user story points for the sprint using the formula: user story points = test cases / productivity rate, where test cases is the estimated number of test cases for the sprint.
#
# Continuously update and execute test cases at the end of each sprint, focusing on comprehensive coverage and alignment with project requirements.
#   - Response:
# ### Test Cases for University Application Portal Development
#
# #### Sprint 1: Account Creation and Program Applications
#
# **User Stories:**
# 1. **User Story 1.1**: Account Creation
# 2. **User Story 1.2**: Program Selection
# 3. **User Story 1.3**: View Applicants
#
# #### Step 1: Identify Test Cases
# - **User Story 1.1 (Account Creation)**
#   - TC1.1.1: Verify successful account creation with valid inputs.
#   - TC1.1.2: Verify error message for duplicate email.
#   - TC1.1.3: Verify error message for invalid email format.
#   - TC1.1.4: Verify password strength requirements.
#
# - **User Story 1.2 (Program Selection)**
#   - TC1.2.1: Verify that all available programs are displayed.
#   - TC1.2.2: Verify selection of a program and submission.
#   - TC1.2.3: Verify handling of empty program selection.
#
# - **User Story 1.3 (View Applicants)**
#   - TC1.3.1: Verify that admissions staff can view a list of applicants.
#   - TC1.3.2: Verify filtering options by program.
#
# **Total Estimated Test Cases for Sprint 1**: 10
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 2 test cases completed per day
#
# #### Step 3: Calculate User Story Points
# - User Story Points (Sprint 1) = 10 test cases / 2 = **5 Points**
#
# ---
#
# #### Sprint 2: Document Uploads and Application Tracking
#
# **User Stories:**
# 1. **User Story 2.1**: Document Upload
# 2. **User Story 2.2**: Application Status Tracking
# 3. **User Story 2.3**: View Uploaded Documents
#
# #### Step 1: Identify Test Cases
# - **User Story 2.1 (Document Upload)**
#   - TC2.1.1: Verify successful document upload with valid files.
#   - TC2.1.2: Verify error message for unsupported file types.
#   - TC2.1.3: Verify error message for file size limit exceeded.
#
# - **User Story 2.2 (Application Status Tracking)**
#   - TC2.2.1: Verify that the correct application status is displayed.
#   - TC2.2.2: Verify real-time updates of application status.
#
# - **User Story 2.3 (View Uploaded Documents)**
#   - TC2.3.1: Verify that admissions staff can view uploaded documents.
#   - TC2.3.2: Verify download functionality for uploaded documents.
#
# **Total Estimated Test Cases for Sprint 2**: 10
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 2 test cases completed per day
#
# #### Step 3: Calculate User Story Points
# - User Story Points (Sprint 2) = 10 test cases / 2 = **5 Points**
#
# ---
#
# #### Sprint 3: Notifications and Communication Tools
#
# **User Stories:**
# 1. **User Story 3.1**: Notification System
# 2. **User Story 3.2**: Communication Channel
#
# #### Step 1: Identify Test Cases
# - **User Story 3.1 (Notification System)**
#   - TC3.1.1: Verify that notifications are sent for important updates.
#   - TC3.1.2: Verify that notifications appear in the user dashboard.
#
# - **User Story 3.2 (Communication Channel)**
#   - TC3.2.1: Verify sending messages to admissions staff.
#   - TC3.2.2: Verify receiving responses from admissions staff.
#
# **Total Estimated Test Cases for Sprint 3**: 6
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 2 test cases completed per day
#
# #### Step 3: Calculate User Story Points
# - User Story Points (Sprint 3) = 6 test cases / 2 = **3 Points**
#
# ---
#
# #### Sprint 4: Integration with University Systems
#
# **User Stories:**
# 1. **User Story 4.1**: Integration with SMS
# 2. **User Story 4.2**: Sync with LMS
# 3. **User Story 4.3**: View Integrated Data
#
# #### Step 1: Identify Test Cases
# - **User Story 4.1 (Integration with SMS)**
#   - TC4.1.1: Verify successful data synchronization with SMS.
#   - TC4.1.2: Verify error handling for failed integration.
#
# - **User Story 4.2 (Sync with LMS)**
#   - TC4.2.1: Verify correct data sync with LMS for enrolled students.
#   - TC4.2.2: Verify error message for failed sync attempts.
#
# - **User Story 4.3 (View Integrated Data)**
#   - TC4.3.1: Verify that admissions staff can view integrated data.
#   - TC4.3.2: Verify data accuracy in the dashboard.
#
# **Total Estimated Test Cases for Sprint 4**: 10
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 2 test cases completed per day
#
# #### Step 3: Calculate User Story Points
# - User Story Points (Sprint 4) = 10 test cases / 2 = **5 Points**
#
# ---
#
# #### Sprint 5: Continuous Improvement and Feature Enhancements
#
# **User Stories:**
# 1. **User Story 5.1**: Financial Aid Information Access
# 2. **User Story 5.2**: Enhanced Reporting Tools
# 3. **User Story 5.3**: Access Library Resources
#
# #### Step 1: Identify Test Cases
# - **User Story 5.1 (Financial Aid Information)**
#   - TC5.1.1: Verify access to financial aid details.
#   - TC5.1.2: Verify the accuracy of displayed financial aid information.
#
# - **User Story 5.2 (Enhanced Reporting Tools)**
#   - TC5.2.1: Verify generation of reports for admissions data.
#   - TC5.2.2: Verify export functionality for reports.
#
# - **User Story 5.3 (Library Resources)**
#   - TC5.3.1: Verify access to library resources from the portal.
#   - TC5.3.2: Verify that resource links are functional.
#
# **Total Estimated Test Cases for Sprint 5**: 10
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 2 test cases completed per day
#
# #### Step 3: Calculate User Story Points
# - User Story Points (Sprint 5) = 10 test cases / 2 = **5 Points**
#
# ---
#
# #### Sprint 6: Final Adjustments and User Testing
#
# **User Stories:**
# 1. **User Story 6.1**: User Feedback Submission
# 2. **User Story 6.2**: Admissions Staff Testing
# 3. **User Story 6.3**: Review Feedback and Adjustments
#
# #### Step 1: Identify Test Cases
# - **User Story 6.1 (User Feedback Submission)**
#   - TC6.1.1: Verify successful submission of user feedback.
#   - TC6.1.2: Verify error handling for feedback submission issues.
#
# - **User Story 6.2 (Admissions Staff Testing)**
#   - TC6.2.1: Verify that admissions staff can access the testing environment.
#   - TC6.2.2: Verify the functionality of all features during testing.
#
# - **User Story 6.3 (Review Feedback and Adjustments)**
#   - TC6.3.1: Verify implementation of feedback adjustments.
#   - TC6.3.2: Verify communication of changes to users and staff.
#
# **Total Estimated Test Cases for Sprint 6**: 10
#
# #### Step 2: Set Productivity Rate
# - **Productivity Rate**: 2 test cases completed per day
#
# #### Step 3: Calculate User Story Points
# - User Story Points (Sprint 6) = 10 test cases / 2 = **5 Points**
#
# ---
#
# ### Summary of User Story Points Across Sprints
#
# - **Sprint 1**: 5 Points
# - **Sprint 2**: 5 Points
# - **Sprint 3**: 3 Points
# - **Sprint 4**: 5 Points
# - **Sprint 5**: 5 Points
# - **Sprint 6**: 5 Points
#
# **Total User Story Points**: **28 Points**
#
# ---
#
# ### Continuous Testing Strategy
#
# 1. **Test Automation**: Prioritize automation for regression testing to ensure rapid feedback and comprehensive coverage as new features are added.
#
# 2. **Continuous Integration**: Integrate testing into the CI/CD pipeline to run test cases automatically after each build.
#
# 3. **Review and Adapt**: Continuously review test cases and adapt them as project requirements evolve, ensuring alignment with the latest user stories and features.
#
# 4. **User Feedback Loop**: Incorporate user feedback into test case design to enhance usability and functionality.
#
# By following this structured approach, the testing process will ensure high software quality, functionality, and performance for the University Application Portal, supporting the agile development lifecycle effectively.
#
# Documentation Engineer:
#   - Message:
# You are a Documentation Engineer Agent. Your role is to create the detailed documentation which includes user documentation and training material based on the software written by the software engineer, design document created by the system engineer, and requirements document created by the requirement engineer.
#
# Then calculate the {{effort}} to write documentation pages in the documentation and training phase in hours, days, weeks, or months, follow the steps below:
# - Step 1: Work = the estimate of total number of documentation pages that will be created for the software project.
# - Step 2: Productivity rate = 3 pages completed every day.
# - Step 3: Effort = Work / Productivity rate.
#
# The amount of {{work}} in this phase is measured by the total number of documentation pages based on the total number of requirements, design document pages, and total number of SLOC written.
#   - Response:
# To estimate the effort required to create user documentation and training materials for the university application portal, we first need to calculate the total number of documentation pages based on the requirements, design documents, and SLOC (Source Lines of Code) written.
#
# ### Step 1: Calculate Work
#
# 1. **Requirements Document Pages**:
#    - The Requirements Document contains detailed sections, including Vision Statement, High-Level Goals, Key Use Cases, User Stories, and User Story Estimation.
#    - Estimated pages for Requirements Document: **10 pages**
#
# 2. **Design Document Pages**:
#    - The Design Document includes System Architecture, UI Design, API Structure, Database Schema, Integration with External Systems, Environment Setup, Scalability, Security Considerations, and User Story Estimation.
#    - Estimated pages for Design Document: **12 pages**
#
# 3. **SLOC Written**:
#    - Total SLOC for all sprints:
#      - Sprint 1: 450 SLOC
#      - Sprint 2: 700 SLOC
#      - Sprint 3: 450 SLOC
#      - Sprint 4: 750 SLOC
#      - Sprint 5: 750 SLOC
#      - Sprint 6: 400 SLOC
#    - Total SLOC = 450 + 700 + 450 + 750 + 750 + 400 = **3,500 SLOC**
#    - Assuming an average of 50 SLOC per page, the estimated number of pages based on SLOC = 3,500 / 50 = **70 pages**
#
# ### Total Documentation Pages Calculation
# - Total Pages = Requirements Document + Design Document + SLOC-based Pages
# - Total Pages = 10 + 12 + 70 = **92 pages**
#
# ### Step 2: Productivity Rate
# - **Productivity Rate**: 3 pages completed every day.
#
# ### Step 3: Calculate Effort
# - **Effort** = Work / Productivity Rate
# - **Effort** = 92 pages / 3 pages/day ≈ **30.67 days**
#
# ### Summary of Effort
# - The estimated effort to create the user documentation and training materials for the university application portal is approximately **31 days**.
#
# ### Documentation and Training Material Outline
# To provide a structured approach for the documentation, here’s a proposed outline for the user documentation and training materials:
#
# 1. **Introduction**
#    - Overview of the University Application Portal
#    - Purpose of the Documentation
#
# 2. **User Guide**
#    - Account Creation
#      - Steps to create an account
#      - Password reset process
#    - Program Application Process
#      - How to select programs
#    - Document Upload Process
#      - Guidelines for document formats and sizes
#    - Application Status Tracking
#      - How to check application status
#    - Notifications and Communication
#      - Understanding notifications
#      - How to communicate with admissions staff
#
# 3. **Admin Guide**
#    - Managing Applications
#      - Viewing applicants
#      - Updating application statuses
#    - Document Management
#      - Accessing uploaded documents
#
# 4. **Integration Points**
#    - Overview of integrations with SMS and LMS
#    - Data synchronization process
#
# 5. **Troubleshooting**
#    - Common issues and solutions
#
# 6. **FAQs**
#    - Frequently asked questions by users
#
# 7. **Training Materials**
#    - User training presentations
#    - Quick reference guides
#    - Walkthrough videos
#
# 8. **Feedback Mechanism**
#    - How users can provide feedback on the portal experience
#
# This structured documentation will provide comprehensive guidance for both users and administrators, ensuring a smooth experience with the university application portal.
#
# ### Conclusion:
# The sprint has been completed successfully, and the team is ready for the next sprint.
